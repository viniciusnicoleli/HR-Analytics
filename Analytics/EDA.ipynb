# %% [markdown]
# # EDA Study

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns

# %%
# Understanding the columns
df = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv", sep=",") ; df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.shape # More than 30 features to be used
# Out:
# (1470, 35)

# %%
from collections import Counter

df_class = df[["BusinessTravel","Attrition","Department","Education","EducationField",
               "RelationshipSatisfaction","StandardHours",
               "StockOptionLevel","YearsSinceLastPromotion","WorkLifeBalance"]]

columns = list(df_class.columns)

lst_columns=list(range(0,35))

kk = list(map(lambda x,col: 'column items:' + ' '+ col + ':' + ' ' + str(Counter(df_class[columns[x]])) ,lst_columns,columns)) ; kk
# Out:
# ["column items: BusinessTravel: Counter({'Travel_Rarely': 1043, 'Travel_Frequently': 277, 'Non-Travel': 150})",
#  "column items: Attrition: Counter({'No': 1233, 'Yes': 237})",
#  "column items: Department: Counter({'Research & Development': 961, 'Sales': 446, 'Human Resources': 63})",
#  'column items: Education: Counter({3: 572, 4: 398, 2: 282, 1: 170, 5: 48})',
#  "column items: EducationField: Counter({'Life Sciences': 606, 'Medical': 464, 'Marketing': 159, 'Technical Degree': 132, 'Other': 82, 'Human Resources': 27})",
#  'column items: RelationshipSatisfaction: Counter({3: 459, 4: 432, 2: 303, 1: 276})',
#  'column items: StandardHours: Counter({80: 1470})',
#  'column items: StockOptionLevel: Counter({0: 631, 1: 596, 2: 158, 3: 85})',
#  'column items: YearsSinceLastPromotion: Counter({0: 581, 1: 357, 2: 159, 7: 76, 4: 61, 3: 52, 5: 45, 6: 32, 11: 24, 8: 18, 9: 17, 15: 13, 13: 10, 12: 10, 14: 9, 10: 6})',
# ...

# %%
df = df.drop(['Over18','EmployeeCount'],axis=1) # Dropping columns that doesn't make any sense, like this one.

# %%
for col in df.columns:
    var = df[col].isna().sum()
    print('The feature',col,'has', var, 'N.A values')
# Out:
# The feature Age has 0 N.A values
# The feature Attrition has 0 N.A values
# The feature BusinessTravel has 0 N.A values
# The feature DailyRate has 0 N.A values
# The feature Department has 0 N.A values
# The feature DistanceFromHome has 0 N.A values
# The feature Education has 0 N.A values
# The feature EducationField has 0 N.A values
# The feature EmployeeNumber has 0 N.A values
# The feature EnvironmentSatisfaction has 0 N.A values
# The feature Gender has 0 N.A values
# The feature HourlyRate has 0 N.A values
# The feature JobInvolvement has 0 N.A values
# The feature JobLevel has 0 N.A values
# The feature JobRole has 0 N.A values
# The feature JobSatisfaction has 0 N.A values
# The feature MaritalStatus has 0 N.A values
# The feature MonthlyIncome has 0 N.A values
# The feature MonthlyRate has 0 N.A values
# The feature NumCompaniesWorked has 0 N.A values
# The feature OverTime has 0 N.A values
# The feature PercentSalaryHike has 0 N.A values
# ...

# %%
_ = sns.histplot(df.Age) ; df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeNumber  \
# ...
